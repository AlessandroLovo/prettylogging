# %%
import prettylogging as plg

# %%
plg.now()

# %%
plg.__version__

# %% [markdown]
# ## Test telegram

# %%
import logging
logger = plg.module_logger
# logger = logging.getLogger('my_logger')
# logger.setLevel(logging.INFO)


with plg.TelegramLogger(logger, '~/telegram_chat_id.txt', '~/prettylogging_bot-token.txt', level=logging.INFO) as tl:
    print(tl.handler)
    print(logger.handlers)
    logger.error('Oh no an error occurred')
    # raise Exception('Test exception')

# %%
logging.getLogger().handlers
